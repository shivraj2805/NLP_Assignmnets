# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\pushk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\pushk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\pushk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\pushk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\pushk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\pushk\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click->nltk) (0.4.6)
# WARNING: Ignoring invalid distribution ~ympy (C:\Users\pushk\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (C:\Users\pushk\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (C:\Users\pushk\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pushk\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pushk\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\pushk\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\pushk\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\pushk\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\pushk\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
text = "Artificial Intelligence is transforming healthcare and education in India."

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

sentences = sent_tokenize(text)
words = word_tokenize(text)

print("Sentences:", sentences)
print("Words:", words)
# Out:
# Sentences: ['Artificial Intelligence is transforming healthcare and education in India.']
# Words: ['Artificial', 'Intelligence', 'is', 'transforming', 'healthcare', 'and', 'education', 'in', 'India', '.']

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words("english"))
filtered_words = [w for w in words if w.lower() not in stop_words and w.isalpha()]

print("Filtered Words:", filtered_words)
# Out:
# Filtered Words: ['Artificial', 'Intelligence', 'transforming', 'healthcare', 'education', 'India']

# %%
from nltk import pos_tag

pos_tags = pos_tag(filtered_words)
print("POS Tags:", pos_tags)
# Out:
# POS Tags: [('Artificial', 'JJ'), ('Intelligence', 'NNP'), ('transforming', 'NN'), ('healthcare', 'NN'), ('education', 'NN'), ('India', 'NNP')]

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(w) for w in filtered_words]

print("Lemmatized Words:", lemmatized)
# Out:
# Lemmatized Words: ['Artificial', 'Intelligence', 'transforming', 'healthcare', 'education', 'India']

# %%
import nltk
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\pushk\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\pushk\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
from nltk import ne_chunk

ner = ne_chunk(pos_tags)
print("Named Entities:")
print(ner)
# Out:
# Named Entities:
# (S
#   Artificial/JJ
#   Intelligence/NNP
#   transforming/NN
#   healthcare/NN
#   education/NN
#   (GPE India/NNP))

# %%
from nltk.probability import FreqDist

freq = FreqDist(filtered_words)
print("Most Common Words:", freq.most_common(5))
# Out:
# Most Common Words: [('Artificial', 1), ('Intelligence', 1), ('transforming', 1), ('healthcare', 1), ('education', 1)]
